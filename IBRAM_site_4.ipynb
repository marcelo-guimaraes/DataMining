# %%
import requests
import urllib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from bs4 import BeautifulSoup

# %%
page = "https://app.anm.gov.br/SIGBM/Publico/GerenciarPublico"
page = requests.get(page)
soup = BeautifulSoup(page.text, 'html.parser')
#soup = soup.get_text(strip=True)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="DNPM - Departamento Nacional de Produção Mineral" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Squadra Tecnologia" name="author"/>
# <title> | DNPM - Departamento Nacional de Produção Mineral</title>
# <!--[if lt IE 9]>
#     <script type="text/javascript">
#         document.createElement('header');
#         document.createElement('nav');
#         document.createElement('section');
#         document.createElement('article');
#         document.createElement('aside');
#         document.createElement('footer');
#     </script>
#     <![endif]-->
# <link href="/SIGBM/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/SIGBM/Content/cssContent?v=IjaTOoDT9FaXU_Q5RZVbPMSrBVBwLSGOnhHldaITeVo1" rel="stylesheet"/>
# <!--[if IE]>
# ...

# %%
filter_soup = re.findall('>(.*?)<',str(soup))
filter_soup
# Out:
# [' | DNPM - Departamento Nacional de Produção Mineral',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'SIGBM - ',
#  'Sistema de Gestão de Segurança de Barragem de Mineração',
#  ' ',
#  'BARRAGENS',
#  'CADASTRO NACIONAL',
#  'ESTATÍSTICAS',
#  'MAPAS',
#  '',
#  'TUTORIAIS',
#  '',
#  ' ',
#  'Empreendedor',
#  '',
#  'Todos',
#  '',
#  'A R Weber Me - 05.742.530/0001-29',
#  '',
#  'ADÃO AFONSO RODUÍ - 469.372.509-91',
#  '',
#  'Agnaldo Celestino de Souza Júnior - 603.446.105-78',
#  '',
#  'Airton Luiz Carus - 355.059.230-20',
#  '',
#  'Alain Stephane Riviere Mineração - 15.264.439/0001-07',
#  '',
#  'Alcoa World Alumina Brasil Ltda. - 06.167.730/0001-68',
#  '',
#  'ALEXANDRE DE CAMPOS LYRA - 829.747.487-91',
#  '',
#  'Alta Floresta Gold Mineração Ltda. - 17.580.707/0001-17',
#  '',
#  'Amg Mineração S.a. - 11.224.676/0001-85',
#  '',
#  'Angelo Carlos Vicari Junior - 923.895.701-00',
#  '',
#  'ANGLO AMERICAN MINERIO DE FERRO BRASIL S/A - 02.359.572/0004-30',
#  '',
# ...

# %%
while '' in filter_soup:
    filter_soup.remove(['', [' ']])
filter_soup
# Out:
# [' | DNPM - Departamento Nacional de Produção Mineral',
#  'SIGBM - ',
#  'Sistema de Gestão de Segurança de Barragem de Mineração',
#  ' ',
#  'BARRAGENS',
#  'CADASTRO NACIONAL',
#  'ESTATÍSTICAS',
#  'MAPAS',
#  'TUTORIAIS',
#  ' ',
#  'Empreendedor',
#  'Todos',
#  'A R Weber Me - 05.742.530/0001-29',
#  'ADÃO AFONSO RODUÍ - 469.372.509-91',
#  'Agnaldo Celestino de Souza Júnior - 603.446.105-78',
#  'Airton Luiz Carus - 355.059.230-20',
#  'Alain Stephane Riviere Mineração - 15.264.439/0001-07',
#  'Alcoa World Alumina Brasil Ltda. - 06.167.730/0001-68',
#  'ALEXANDRE DE CAMPOS LYRA - 829.747.487-91',
#  'Alta Floresta Gold Mineração Ltda. - 17.580.707/0001-17',
#  'Amg Mineração S.a. - 11.224.676/0001-85',
#  'Angelo Carlos Vicari Junior - 923.895.701-00',
#  'ANGLO AMERICAN MINERIO DE FERRO BRASIL S/A - 02.359.572/0004-30',
#  'Anglo American Níquel Brasil Ltda. - 42.184.226/0001-30',
#  'Anglo American Níquel Brasil Ltda. - 42.184.226/0019-69',
# ...

# %%
pd.Series(filter_soup)
# Out:
# 0        | DNPM - Departamento Nacional de Produção Mi...
# 1                                                SIGBM -
# 2       Sistema de Gestão de Segurança de Barragem de ...
# 3
# 4                                               BARRAGENS
#                               ...
# 1458                                    " + list.Text + "
# 1459                                               Todos
# 1460                                    " + list.Text + "
# 1461                                     " + dataHtml + "
# 1462                                         " + data + "
# Length: 1463, dtype: object
